# %%
# dataset link
# https://www.kaggle.com/datasets/neisse/scrapped-lyrics-from-6-genres

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load data

# %%
#df_artists=pd.read_csv(r'C:\Users\NR200\Desktop\artists-data.csv')
df_artists=pd.read_csv('/content/drive/MyDrive/IR_CW3_data/artists-data.csv')
df_artists
# Out:
#                    Artist                           Genres  Songs  Popularity  \
# 0           Ivete Sangalo              Pop; Axé; Romântico  313.0         4.4
# 1     Chiclete com Banana                              Axé  268.0         3.8
# 2               Banda Eva           Axé; Romântico; Reggae  215.0         2.3
# 3               É O Tchan                              Axé  129.0         1.6
# 4          Claudia Leitte              Pop; Axé; Romântico  167.0         1.5
# ...                   ...                              ...    ...         ...
# 4163        Miriam Makeba  World Music; Black Music; Blues   17.0         0.0
# 4164      Freddie Aguilar                      World Music   61.0         0.0
# 4165      Amadou & Mariam                      World Music   14.0         0.0
# 4166         Magic System    World Music; Gospel/Religioso   16.0         0.0
# 4167         Johnny Clegg    World Music; Gospel/Religioso   34.0         0.0
#
#                        Link
# ...

# %%
#Check for missing rows

# %%
missing=df_artists.loc[df_artists.isnull().any(axis=1)]
print('Rows with missing data: {}'.format(missing.shape[0]))
print('Percentage of rows with missing data: {:.3f}%'.format(missing.shape[0]/df_artists.shape[0]*100))
missing
# Out:
# Rows with missing data: 6
# Percentage of rows with missing data: 0.144%
#               Artist           Genres  Songs  Popularity              Link
# 118              NaN              NaN    NaN         NaN               NaN
# 464            ≛NXT≛  Dance; MPB; Pop    1.0         NaN             /nxt/
# 587          Dj Ralk              NaN    1.0         0.0         /dj-ralk/
# 1987           Jeezy              NaN    7.0         0.0           /jeezy/
# 2014  Rylo Rodriguez              NaN    1.0         0.0  /rylo-rodriguez/
# 2368       Yuko Ando              NaN   30.0         0.0       /yuko-ando/

# %%
#df_lyrics=pd.read_csv(r'C:\Users\NR200\Desktop\lyrics-data.csv')
df_lyrics=pd.read_csv('/content/drive/MyDrive/IR_CW3_data/lyrics-data.csv')
df_lyrics=df_lyrics.loc[df_lyrics.language=='en'].reset_index()
df_lyrics
# Out:
#          index            ALink  \
# 0           69  /ivete-sangalo/
# 1           86  /ivete-sangalo/
# 2           88  /ivete-sangalo/
# 3          111  /ivete-sangalo/
# 4          140  /ivete-sangalo/
# ...        ...              ...
# 191809  379926   /clegg-johnny/
# 191810  379927   /clegg-johnny/
# 191811  379928   /clegg-johnny/
# 191812  379929   /clegg-johnny/
# 191813  379930   /clegg-johnny/
#
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# ...

# %%
#Check for missing rows

# %%
missing=df_lyrics.loc[df_lyrics.isnull().any(axis=1)]
print('Rows with missing data: {}'.format(missing.shape[0]))
print('Percentage of rows with missing data: {:.3f}%'.format(missing.shape[0]/df_lyrics.shape[0]*100))
missing
# Out:
# Rows with missing data: 2
# Percentage of rows with missing data: 0.001%
#          index                  ALink SName                           SLink  \
# 86840   163380  /motionless-in-white/   NaN  /motionless-in-white/c0de.html
# 115616  196723             /blossoms/   NaN             /blossoms/blow.html
#
#                                                     Lyric language
# 86840   Everything you know in the focus\nLive in the ...       en
# 115616  The cold road is all I know\nThe old road is w...       en

# %%
#Get column with artists' names

# %%
artists_dict=dict(zip(df_artists.Link,df_artists.Artist))

# %%
def Artists_function(row):
    if row.ALink in artists_dict:
         return artists_dict[row.ALink]
    return
    
df_lyrics = df_lyrics.assign(Actual_Artist_Name = df_lyrics.apply(Artists_function, axis=1))
df_lyrics
# Out:
#          index            ALink  \
# 0           69  /ivete-sangalo/
# 1           86  /ivete-sangalo/
# 2           88  /ivete-sangalo/
# 3          111  /ivete-sangalo/
# 4          140  /ivete-sangalo/
# ...        ...              ...
# 191809  379926   /clegg-johnny/
# 191810  379927   /clegg-johnny/
# 191811  379928   /clegg-johnny/
# 191812  379929   /clegg-johnny/
# 191813  379930   /clegg-johnny/
#
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# ...

# %%
#Delete useless columns
df_lyrics = df_lyrics.drop(columns=['index', 'ALink', 'SLink', 'language'])
df_lyrics
# Out:
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# 191811      Warsaw 1943 (I Never Betrayed The Revolution)
# 191812                         When The System Has Fallen
# 191813                                Woman Be My Country
#
#                                                     Lyric Actual_Artist_Name
# 0       I feel so unsure\nAs I take your hand and lead...      Ivete Sangalo
# 1       Don't let them fool, ya\nOr even try to school...      Ivete Sangalo
# ...

# %%
#Replace \n with space in lyrics

# %%
df_lyrics.Lyric=df_lyrics.Lyric.replace(r'\n',' ', regex=True)

# %%
df_lyrics
# Out:
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# 191811      Warsaw 1943 (I Never Betrayed The Revolution)
# 191812                         When The System Has Fallen
# 191813                                Woman Be My Country
#
#                                                     Lyric Actual_Artist_Name
# 0       I feel so unsure As I take your hand and lead ...      Ivete Sangalo
# 1       Don't let them fool, ya Or even try to school,...      Ivete Sangalo
# ...

# %%
df_lyrics=df_lyrics.sample(frac=0.00521)
df_lyrics

# %%
#Tokenize and lemmatize lyrics

# %%
df_lyrics = df_lyrics.assign(Lyric_lemmatized = np.nan)
df_lyrics
# Out:
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# 191811      Warsaw 1943 (I Never Betrayed The Revolution)
# 191812                         When The System Has Fallen
# 191813                                Woman Be My Country
#
#                                                     Lyric Actual_Artist_Name  \
# 0       I feel so unsure As I take your hand and lead ...      Ivete Sangalo
# 1       Don't let them fool, ya Or even try to school,...      Ivete Sangalo
# ...

# %%
from nltk.corpus import wordnet
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
#code source https://www.machinelearningplus.com/nlp/lemmatization-examples-python/
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)


# 1. Init Lemmatizer
lemmatizer = WordNetLemmatizer()


def tokenizer_and_lemmatizer(sentence):
  return [lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence)]

# %%
# !pip install tqdm

# %%
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
#df_lyrics.Lyric_lemmatized = df_lyrics.Lyric.progress_apply(tokenizer_and_lemmatizer)
#df_lyrics.to_csv('out1.csv', sep='\t')
#df_lyrics

# %%
#example that doesnt take too long
tqdm_notebook.pandas()
df_lyrics.Lyric_lemmatized[0:100] = df_lyrics.Lyric[0:100] .progress_apply(tokenizer_and_lemmatizer)
df_lyrics
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#                                                     SName  \
# 0                                        Careless Whisper
# 1       Could You Be Loved / Citação Musical do Rap: S...
# 2                                  Cruisin' (Part. Saulo)
# 3                                                    Easy
# 4                       For Your Babies (The Voice cover)
# ...                                                   ...
# 191809                                        The Waiting
# 191810                              Too Early For The Sky
# 191811      Warsaw 1943 (I Never Betrayed The Revolution)
# 191812                         When The System Has Fallen
# 191813                                Woman Be My Country
#
#                                                     Lyric Actual_Artist_Name  \
# 0       I feel so unsure As I take your hand and lead ...      Ivete Sangalo
# ...

# %%
#Lowercasing

#df_lyrics.Lyric_lemmatized=df_lyrics.Lyric_lemmatized.str.lower()
#df_lyrics
